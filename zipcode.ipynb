# %%
import pandas as pd
import numpy as np
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

# %%
import seaborn as sb
# seaborn the dataviz api to use
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
p_zip = pd.read_csv("HomePrice_ZipCode.csv")
# Out:
# C:\Users\Amber\Anaconda2\envs\py3k\lib\site-packages\IPython\core\interactiveshell.py:2717: DtypeWarning: Columns (246,248) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
p_zip.head()
# Out:
#    RegionID  RegionName      City State     Metro CountyName  SizeRank  \
# 0   84654.0     60657.0   Chicago    IL   Chicago       Cook       1.0
# 1   84616.0     60614.0   Chicago    IL   Chicago       Cook       2.0
# 2   93144.0     79936.0   El Paso    TX   El Paso    El Paso       3.0
# 3   84640.0     60640.0   Chicago    IL   Chicago       Cook       4.0
# 4   61807.0     10467.0  New York    NY  New York      Bronx       5.0
#
#     1996-04   1996-05   1996-06    ...        2017-03    2017-04    2017-05  \
# 0  420800.0  423500.0  426200.0    ...      1087500.0  1080200.0  1073700.0
# 1  542400.0  546700.0  551700.0    ...      1526300.0  1527000.0  1524600.0
# 2   70900.0   71200.0   71100.0    ...       114000.0   113800.0   114000.0
# 3  298200.0  297400.0  295300.0    ...       735700.0   728400.0   726800.0
# 4       NaN       NaN       NaN    ...       392700.0   396300.0   399100.0
#
#      2017-06    2017-07    2017-08    2017-09    2017-10    2017-11    2017-12
# ...

# %%
p_zip['NameID'] = p_zip['City'] + p_zip['RegionName'].astype(str)

# %%
p_zip.head(1)
# Out:
#    RegionID  RegionName     City State    Metro CountyName  SizeRank  \
# 0   84654.0     60657.0  Chicago    IL  Chicago       Cook       1.0
#
#     1996-04   1996-05   1996-06       ...          2017-04    2017-05  \
# 0  420800.0  423500.0  426200.0       ...        1080200.0  1073700.0
#
#      2017-06    2017-07    2017-08    2017-09    2017-10    2017-11  \
# 0  1064100.0  1052600.0  1047600.0  1047700.0  1047600.0  1048800.0
#
#      2017-12          NameID
# 0  1051600.0  Chicago60657.0
#
# [1 rows x 269 columns]

# %%
p_zipdrop = p_zip.drop(['City', 'RegionID', 'RegionName', 'State', 'Metro', 'CountyName', 'SizeRank'], axis=1)

# %%
T_pzip = p_zipdrop.set_index('NameID').T

# %%
T_pzip.tail(10)
# Out:
# NameID  Chicago60657.0 Chicago60614.0 El Paso79936.0 Chicago60640.0  \
# 2017-03     1.0875e+06     1.5263e+06         114000         735700
# 2017-04     1.0802e+06      1.527e+06         113800         728400
# 2017-05     1.0737e+06     1.5246e+06         114000         726800
# 2017-06     1.0641e+06     1.5166e+06         114000         724900
# 2017-07     1.0526e+06     1.5125e+06         113800         717200
# 2017-08     1.0476e+06     1.5137e+06         113700         709400
# 2017-09     1.0477e+06     1.5136e+06         114200         707700
# 2017-10     1.0476e+06     1.5081e+06         114300         708300
# 2017-11     1.0488e+06     1.5023e+06         114000         704800
# 2017-12     1.0516e+06     1.4963e+06         114000         700900
#
# NameID  New York10467.0 Houston77084.0 San Francisco94109.0 McKinney75070.0  \
# 2017-03          392700         154700           3.9121e+06          313300
# ...

# %%
T_pzip.index = pd.to_datetime(T_pzip.index)

# %%
T_pzip.shape
# Out:
# (261, 15339)

# %% [markdown]
# df.drop(df.columns[[1, 69]], axis=1, inplace=True)

# %%
T_pzip.drop(T_pzip.columns[[15338]], axis=1, inplace=True)
T_pzip.shape
T_pzip.head(1)
# Out:
# (261, 15338)
# NameID     Chicago60657.0 Chicago60614.0 El Paso79936.0 Chicago60640.0  \
# 1996-04-01         420800         542400          70900         298200
#
# NameID     New York10467.0 Houston77084.0 San Francisco94109.0  \
# 1996-04-01             NaN          76700                  NaN
#
# NameID     McKinney75070.0 New York11226.0 Cypress77449.0  \
# 1996-04-01             NaN             NaN          72300
#
# NameID              ...           Port Ewen12429.0 Herbster54844.0  \
# 1996-04-01          ...                      75400          201000
#
# NameID     Rhododendron97028.0 Bethel12720.0 Shelburne Falls1338.0  \
# 1996-04-01              146900         68300                 98900
#
# NameID     Arch Cape97102.0 Fairhope36564.0 Woodstock3293.0 Annapolis21405.0  \
# 1996-04-01              NaN             NaN           86700           253500
#
# NameID     Apache Junction85220.0
# 1996-04-01                    NaN
#
# [1 rows x 15338 columns]

# %%
T_pzip = T_pzip.fillna(0)

# %%
T_pzip = T_pzip.astype(float)

# %% [markdown]
# df['f']=df.iloc[:,0:2].sum(axis=1) <br>
# df[df[A]!=0].mean()

# %%
T_pzip['Total']=T_pzip.iloc[:,0:15337].sum(axis=1)

# %%
T_pzip['Average']=T_pzip.iloc[:,0:15337].mean(axis=1)

# %%
T_pzip.head()
T_pzip.shape
# Out:
# NameID      Chicago60657.0  Chicago60614.0  El Paso79936.0  Chicago60640.0  \
# 1996-04-01        420800.0        542400.0         70900.0        298200.0
# 1996-05-01        423500.0        546700.0         71200.0        297400.0
# 1996-06-01        426200.0        551700.0         71100.0        295300.0
# 1996-07-01        428600.0        565000.0         71300.0        294600.0
# 1996-08-01        429900.0        574200.0         71400.0        295700.0
#
# NameID      New York10467.0  Houston77084.0  San Francisco94109.0  \
# 1996-04-01              0.0         76700.0                   0.0
# 1996-05-01              0.0         76500.0                   0.0
# 1996-06-01              0.0         76000.0                   0.0
# 1996-07-01              0.0         75800.0                   0.0
# 1996-08-01              0.0         75700.0                   0.0
#
# NameID      McKinney75070.0  New York11226.0  Cypress77449.0      ...       \
# ...

# %%
T_pzip[('Chicago60657.0')].resample('M').sum().plot(figsize=(20,6))

# %%
T_pzip.iloc[:,0:4].resample('M').sum().plot(figsize=(20,6))

# %%
T_pzip['Total'].resample('M').sum().plot(figsize=(20,6))

# %%
T_pzip['Average'].resample('M').mean().plot(figsize=(20,6))

# %%
T_pzip['month'] = T_pzip.index.month

# %%
T_pzip['Total'].groupby(T_pzip['month']).sum().plot(figsize=(20,6))

# %% [markdown]
# ## By Month

# %%
T_pzip['Average'].groupby(T_pzip['month']).mean().plot(figsize=(20,6))

# %%
import plotly
plotly.offline.init_notebook_mode(connected=True)
# Out:
# <script>requirejs.config({paths: { 'plotly': ['https://cdn.plot.ly/plotly-latest.min']},});if(!window.Plotly) {{require(['plotly'],function(plotly) {window.Plotly=plotly;});}}</script>

# %%
from plotly import __version__
from plotly.offline import download_plotlyjs, init_notebook_mode, plot, iplot

print (__version__ )
# Out:
# 2.7.0

# %%
# plotly.tools.set_credentials_file(username='akell47', api_key='***')

# %%
import plotly.plotly as py
import plotly.graph_objs as go

df = T_pzip

avgP = go.Scatter(
    x=T_pzip.index,
    y=df['Average'],
    name = "Average",
    line = dict(color = '#17BECF'),
    opacity = 0.8)

# trace_low = go.Scatter(
#     x=df.Date,
#     y=df['AAPL.Low'],
#     name = "AAPL Low",
#     line = dict(color = '#7F7F7F'),
#     opacity = 0.8)

data = [avgP]

layout = dict(
    title='Average National Home Values by Zipcode',
    xaxis=dict(
        rangeselector=dict(
            buttons=list([
#                 dict(count=1,
#                      label='1m',
#                      step='month',
#                      stepmode='backward'),
                dict(count=6,
                     label='6m',
                     step='month',
                     stepmode='backward'),
                dict(step='all')
            ])
        ),
        rangeslider=dict(),
        type='date'
    )
)

fig = dict(data=data, layout=layout)
py.iplot(fig, filename = "HomePriceZipCode")
# Out:
# ---------------------------------------------------------------------------
# PlotlyRequestError                        Traceback (most recent call last)
# <ipython-input-31-20404d3e01dc> in <module>()
#      42
#      43 fig = dict(data=data, layout=layout)
# ---> 44 py.iplot(fig, filename = "HomePriceZipCode")
#
# C:\Users\Amber\Anaconda2\envs\py3k\lib\site-packages\plotly\plotly\plotly.py in iplot(figure_or_data, **plot_options)
#     138     if 'auto_open' not in plot_options:
#     139         plot_options['auto_open'] = False
# --> 140     url = plot(figure_or_data, **plot_options)
#     141
#     142     if isinstance(figure_or_data, dict):
#
# C:\Users\Amber\Anaconda2\envs\py3k\lib\site-packages\plotly\plotly\plotly.py in plot(figure_or_data, validate, **plot_options)
#     231     data = fig.get('data', [])
#     232     plot_options['layout'] = fig.get('layout', {})
# --> 233     response = v1.clientresp(data, **plot_options)
#     234
# ...

# %%
p_hood = pd.read_csv("HomePrice_Neighborhood.csv")
p_hood.shape
p_hood.head()
# Out:
# (5632, 268)
#    RegionID         RegionName         City State  \
# 0  274772.0   Northeast Dallas       Dallas    TX
# 1  192689.0           Paradise    Las Vegas    NV
# 2  112345.0           Maryvale      Phoenix    AZ
# 3   27080.0       Sherman Oaks  Los Angeles    CA
# 4  118208.0  South Los Angeles  Los Angeles    CA
#
#                             Metro   CountyName  SizeRank   1996-04   1996-05  \
# 0               Dallas-Fort Worth       Dallas       1.0       NaN       NaN
# 1                       Las Vegas        Clark       2.0  131400.0  131200.0
# 2                         Phoenix     Maricopa       3.0   60000.0   59900.0
# 3  Los Angeles-Long Beach-Anaheim  Los Angeles       4.0  261900.0  264400.0
# 4  Los Angeles-Long Beach-Anaheim  Los Angeles       5.0  117900.0  118800.0
#
#     1996-06    ...        2017-03    2017-04    2017-05    2017-06    2017-07  \
# 0       NaN    ...       316200.0   320000.0   323700.0   323900.0   322100.0
# ...

# %%
atlanta = p_hood[p_hood['City']=='Atlanta']
atlanta.shape
atlanta.head()
# Out:
# (59, 268)
#       RegionID       RegionName     City State    Metro CountyName  SizeRank  \
# 614   126858.0      Ansley Park  Atlanta    GA  Atlanta     Fulton    4239.0
# 1074  269246.0  Ashview Heights  Atlanta    GA  Atlanta     Fulton    4930.0
# 1163  127281.0           Bolton  Atlanta    GA  Atlanta     Fulton    3767.0
# 1494  127407.0       Brookhaven  Atlanta    GA  Atlanta     Fulton    3745.0
# 1497  127432.0  Brookwood Hills  Atlanta    GA  Atlanta     Fulton    4038.0
#
#        1996-04   1996-05   1996-06    ...        2017-03    2017-04  \
# 614   372400.0  378500.0  384700.0    ...      1125900.0  1133600.0
# 1074   56300.0   55200.0   54600.0    ...        54500.0    54900.0
# 1163  169400.0  165600.0  164900.0    ...       358600.0   359400.0
# 1494  542400.0  531000.0  525700.0    ...      1359100.0  1358700.0
# 1497  439800.0  442400.0  448300.0    ...      1106600.0  1121100.0
#
#         2017-05    2017-06    2017-07    2017-08    2017-09    2017-10  \
# ...

# %%
atlantadrop = atlanta.drop(['RegionID','City','State','Metro','CountyName','SizeRank'], axis=1)

# %%
T_patlanta = atlantadrop.set_index('RegionName').T
T_patlanta.index = pd.to_datetime(T_patlanta.index)
T_patlanta.shape
T_patlanta.head()
# Out:
# (261, 59)
# RegionName  Ansley Park  Ashview Heights    Bolton  Brookhaven  \
# 1996-04-01     372400.0          56300.0  169400.0    542400.0
# 1996-05-01     378500.0          55200.0  165600.0    531000.0
# 1996-06-01     384700.0          54600.0  164900.0    525700.0
# 1996-07-01     389700.0          54000.0  166100.0    528400.0
# 1996-08-01     391600.0          53100.0  166500.0    530500.0
#
# RegionName  Brookwood Hills  Browns Mill Park  Buckhead Forest  Cabbagetown  \
# 1996-04-01         439800.0           48300.0         225700.0      92200.0
# 1996-05-01         442400.0           48600.0         230300.0      93500.0
# 1996-06-01         448300.0           49000.0         232500.0      93700.0
# 1996-07-01         453100.0           49600.0         231800.0      93800.0
# 1996-08-01         452000.0           50000.0         231900.0      93800.0
#
# RegionName  Campbellton Road  Candler Park              ...               \
# ...

# %%
T_patlanta = T_patlanta.fillna(0)
T_patlanta = T_patlanta.astype(float)
T_patlanta['Total']=T_patlanta.iloc[:,0:58].sum(axis=1)
# T_patlanta['Average']=T_patlanta[T_patlanta.iloc[:,0:58]!=0].mean(axis=1)
T_patlanta['Average']=T_patlanta.iloc[:,0:58].mean(axis=1)
T_patlanta.head(1)
# Out:
# RegionName  Ansley Park  Ashview Heights    Bolton  Brookhaven  \
# 1996-04-01     372400.0          56300.0  169400.0    542400.0
#
# RegionName  Brookwood Hills  Browns Mill Park  Buckhead Forest  Cabbagetown  \
# 1996-04-01         439800.0           48300.0         225700.0      92200.0
#
# RegionName  Campbellton Road  Candler Park      ...        \
# 1996-04-01           54700.0      166600.0      ...
#
# RegionName  South River Gardens  Southwest  Springlake  Summerhill  \
# 1996-04-01                  0.0    77100.0    282400.0     95500.0
#
# RegionName  Tuxedo Park  Underwood Hills  Virginia Highland  \
# 1996-04-01     832100.0         173300.0           231300.0
#
# RegionName  West Paces Ferry - Northside       Total        Average
# 1996-04-01                      457000.0  11980700.0  206563.793103
#
# [1 rows x 61 columns]

# %%
T_patlanta['Normalized'] = T_patlanta['Average'] / T_patlanta['Average'].loc[0,]

# %%
T_pzip['Normalized'] = T_pzip['Average'] / T_pzip['Average'].loc[0,]

# %% [markdown]
# ## Atlanta Average Neighborhood Home Prices and National Average Zipcode Home Price

# %%
T_patlanta[('Normalized')].resample('M').mean().plot(figsize=(20,6),color='red')#Atlanta
T_pzip['Normalized'].resample('M').mean().plot(figsize=(20,6),color='navy')#National

# %%
T_patlanta[('Average')].resample('M').mean().plot(figsize=(20,6),color='red')#Atlanta
T_pzip['Average'].resample('M').mean().plot(figsize=(20,6),color='navy')#National

# %%
T_patlanta[('Ansley Park')].resample('M').mean().plot(figsize=(20,6),color='red')
T_patlanta[('Grant Park')].resample('M').mean().plot(figsize=(20,6),color='orange')
T_patlanta[('Garden Hills')].resample('M').mean().plot(figsize=(20,6),color='yellow')
T_patlanta[('Old Fourth Ward')].resample('M').mean().plot(figsize=(20,6),color='green')
T_patlanta[('Reynoldstown')].resample('M').mean().plot(figsize=(20,6),color='blue')
T_patlanta[('Average')].resample('M').mean().plot(figsize=(20,6),color='grey')
T_pzip['Average'].resample('M').mean().plot(figsize=(20,6),color='black')

# %%
patlanta = T_patlanta.drop(['Total'], axis=1)

# %%
neighborhoodList = list(patlanta.columns.values)
patlanta[neighborhoodList].resample('M').mean().plot(figsize=(40,40))

# %%
df = patlanta

avgP = go.Scatter(
    x=df.index,
    y=df[('Average')],
    name = "Atlanta Neighborhoods",
    line = dict(color = '#17BECF'),
    opacity = 0.8)

# trace_low = go.Scatter(
#     x=df.Date,
#     y=df['AAPL.Low'],
#     name = "AAPL Low",
#     line = dict(color = '#7F7F7F'),
#     opacity = 0.8)

data = [avgP]

layout = dict(
    title='Average Atlanta Home Values',
    xaxis=dict(
        rangeselector=dict(
            buttons=list([
#                 dict(count=1,
#                      label='1m',
#                      step='month',
#                      stepmode='backward'),
                dict(count=6,
                     label='6m',
                     step='month',
                     stepmode='backward'),
                dict(step='all')
            ])
        ),
        rangeslider=dict(),
        type='date'
    )
)

fig = dict(data=data, layout=layout)
py.iplot(fig, filename = "HomePriceAtlanta")

# %%
print (neighborhoodList)

# %%
df = patlanta

AP = go.Scatter(
    x=df.index,
    y=df[('Ansley Park')],
    name = "Ansley Park",
    line = dict(color = '#17BECF'),
    opacity = 0.8)

CR = go.Scatter(
    x=df.index,
    y=df[('Campbellton Road')],
    name = "Campbellton Road",
    line = dict(color = '#7F7F7F'),
    opacity = 0.8)

GH = go.Scatter(
    x=df.index,
    y=df[('Garden Hills')],
    name = "Garden Hills",
    line = dict(color = '#00ff00'),
    opacity = 0.8)

OFW = go.Scatter(
    x=df.index,
    y=df[('Old Fourth Ward')],
    name = "Old Fourth Ward",
    line = dict(color = '#ff00ff'),
    opacity = 0.8)

GH = go.Scatter(
    x=df.index,
    y=df[('Garden Hills')],
    name = "Garden Hills",
    line = dict(color = '#3366ff'),
    opacity = 0.8)

MS = go.Scatter(
    x=df.index,
    y=df[('Mechanicsville')],
    name = "Mechanisville",
    line = dict(color = '#000099'),
    opacity = 0.8)

GP = go.Scatter(
    x=df.index,
    y=df[('Grant Park')],
    name = "Grant Park",
    line = dict(color = '#660033'),
    opacity = 0.8)


MC = go.Scatter(
    x=df.index,
    y=df[('Midwest Cascade')],
    name = "Midwest Cascade",
    line = dict(color = '#ccff33'),
    opacity = 0.8)

MT = go.Scatter(
    x=df.index,
    y=df[('Midtown')],
    name = "Midtown",
    line = dict(color = '#ff0000'),
    opacity = 0.8)

SH = go.Scatter(
    x=df.index,
    y=df[('Summerhill')],
    name = "Summerhill",
    line = dict(color = '#ff0000'),
    opacity = 0.8)

MT = go.Scatter(
    x=df.index,
    y=df[('Kirkwood')],
    name = "Kirkwood",
    line = dict(color = '#009933'),
    opacity = 0.8)

EA = go.Scatter(
    x=df.index,
    y=df[('East Atlanta')],
    name = "East Atlanta",
    line = dict(color = '#ffff00'),
    opacity = 0.8)

NB = go.Scatter(
    x=df.index,
    y=df[('North Buckhead')],
    name = "North Buckhead",
    line = dict(color = '#66ccff'),
    opacity = 0.8)

CP = go.Scatter(
    x=df.index,
    y=df[('Chastain Park')],
    name = "Chastain Park",
    line = dict(color = '#ff9999'),
    opacity = 0.8)

data = [AP, CR, GH, MS, GP, MC, MT, SH, MT, EA, NB, CP]

layout = dict(
    title='Average Atlanta Neighborhoods Home Values',
    xaxis=dict(
        rangeselector=dict(
            buttons=list([
#                 dict(count=1,
#                      label='1m',
#                      step='month',
#                      stepmode='backward'),
                dict(count=6,
                     label='6m',
                     step='month',
                     stepmode='backward'),
                dict(step='all')
            ])
        ),
        rangeslider=dict(),
        type='date',
        
    )
)

fig = dict(data=data, layout=layout)
py.iplot(fig, filename = "HomePriceAtlantaNeighborhoods")

# %%
df = patlanta


for neighborhood in neighborhoodList:
    NH = go.Scatter(
        x=df.index,
        y=df[(neighborhood)],
        name = "Neighborhoods",
        line = dict(color = '#17BECF'),
        opacity = 0.8)


data = [NH]

layout = dict(
    title='Average Atlanta Neighborhoods Home Values',
    xaxis=dict(
        rangeselector=dict(
            buttons=list([
#                 dict(count=1,
#                      label='1m',
#                      step='month',
#                      stepmode='backward'),
                dict(count=6,
                     label='6m',
                     step='month',
                     stepmode='backward'),
                dict(step='all')
            ])
        ),
        rangeslider=dict(),
        type='date',
        
    )
)

fig = dict(data=data, layout=layout)
py.iplot(fig, filename = "HomePriceAtlantaNeighborhoods")
